# %% [markdown]
# ### Image Pipelines:
# - Real life datasets can be large or small
# - Image pipelines are an efficient way to handle large datasets
# - When we have a large dataset, we want to load images batch by batch => We create image pipeline
#
#
# ### Data Augmentation:
# - Technique of augmenting data, which acts as a regularizer to reduce overfitting

# %% [markdown]
# #### Tiny-ImageNet-200 Dataset:
# - Subset of ImageNet dataset (1,000,000 images in 1000 output classes)
# - 100,000 train images
# - 10,000 test images
# - 10,000 val images
# - 200 output classes

# %%
import numpy as np
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
train_gen = ImageDataGenerator(rescale=1/255.0,
                               rotation_range=40,
                               width_shift_range=0.2,
                               height_shift_range=0.3,
                               shear_range=0.2,
                               zoom_range=0.3,
                               horizontal_flip=True,
                               vertical_flip=True
                             )

# Augmentating each batch of training dataset with some variations

# %%
test_gen = ImageDataGenerator(rescale=1/255.0)
# Not augmentating test set as we dont need extra data

# %%
generator = train_gen.flow_from_directory("tiny-imagenet-200/train", target_size=(224,224), 
                                           batch_size=128, class_mode='categorical')
# Out:
# Found 100000 images belonging to 200 classes.

# %%
type(generator.class_indices)
# generator.class_indices
# Out:
# dict

# %%
x, y = generator.next()
print(x.shape)
print(y.shape)
# Out:
# (128, 224, 224, 3)
# (128, 200)

# %%
for i in range(5):
    plt.imshow(x[i])
    plt.show()

# %%
class_ids = generator.class_indices
print(class_ids)
# Out:
# {'n01443537': 0, 'n01629819': 1, 'n01641577': 2, 'n01644900': 3, 'n01698640': 4, 'n01742172': 5, 'n01768244': 6, 'n01770393': 7, 'n01774384': 8, 'n01774750': 9, 'n01784675': 10, 'n01855672': 11, 'n01882714': 12, 'n01910747': 13, 'n01917289': 14, 'n01944390': 15, 'n01945685': 16, 'n01950731': 17, 'n01983481': 18, 'n01984695': 19, 'n02002724': 20, 'n02056570': 21, 'n02058221': 22, 'n02074367': 23, 'n02085620': 24, 'n02094433': 25, 'n02099601': 26, 'n02099712': 27, 'n02106662': 28, 'n02113799': 29, 'n02123045': 30, 'n02123394': 31, 'n02124075': 32, 'n02125311': 33, 'n02129165': 34, 'n02132136': 35, 'n02165456': 36, 'n02190166': 37, 'n02206856': 38, 'n02226429': 39, 'n02231487': 40, 'n02233338': 41, 'n02236044': 42, 'n02268443': 43, 'n02279972': 44, 'n02281406': 45, 'n02321529': 46, 'n02364673': 47, 'n02395406': 48, 'n02403003': 49, 'n02410509': 50, 'n02415577': 51, 'n02423022': 52, 'n02437312': 53, 'n02480495': 54, 'n02481823': 55, 'n02486410': 56, 'n02504458': 57, 'n02509815': 58, 'n02
# ...

# %%
import os, keras

# %%
def load_validation_data(target_size, num_of_classes):
    with open(os.path.join("tiny-imagenet-200/val/", "val_annotations.txt")) as f:
        lines = f.readlines()
        
        m = len(lines)
        X = np.empty((m, *target_size, 3))
        y = np.empty(m, dtype=int)
        
        for i, line in enumerate(lines):
            tokens = line.split()
            
            img_name = tokens[0]
            img_label = tokens[1]
            img_url = os.path.join("tiny-imagenet-200/val/images", img_name)
            
            img = image.load_img(img_url)
            img = img.resize(target_size)
            
            X[i, ] = np.array(img, dtype=np.float32)/255.0
            y[i] = class_ids[img_label]
            img.close()
            
        return X, keras.utils.to_categorical(y, num_classes = num_of_classes)

# %%
X_val, Y_val = load_validation_data((224,224), 200)

print(X_val.shape)
print(Y_val.shape)
# Out:
# (10000, 224, 224, 3)
# (10000, 200)

# %%
# Now, feed this to a CNN model and train using fit_generator() method and pass validation data as well
