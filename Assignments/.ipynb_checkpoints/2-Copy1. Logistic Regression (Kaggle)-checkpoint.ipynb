# %% [markdown]
# $LL(\theta) = y^{(i)}log(h_\theta x^{(i)}) + (1 - y^{(i)})log(1 - h_\theta x^{(i)})$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data = pd.read_csv("../Kaggle/Datasets/all (LogReg)/Train.csv")
d2 = pd.read_csv("../Kaggle/Datasets/all (LogReg)/Test.csv")

# print(data.shape)
print(data.columns)
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age          197
# sibsp          0
# parch          0
# ticket         0
# fare           1
# cabin        780
# embarked       1
# boat         635
# body         911
# home.dest    427
# dtype: int64

# %%
data.head()
# Out:
#    pclass  survived                                            name     sex  \
# 0     3.0       0.0                         O'Donoghue, Ms. Bridget  female
# 1     2.0       0.0  Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male
# 2     2.0       1.0                       Smith, Miss. Marion Elsie  female
# 3     3.0       1.0  Goldsmith, Mrs. Frank John (Emily Alice Brown)  female
# 4     3.0       1.0                              McCoy, Miss. Agnes  female
#
#     age  sibsp  parch  ticket    fare cabin embarked boat  body  \
# 0   NaN    0.0    0.0  364856   7.750   NaN        Q  NaN   NaN
# 1  39.0    0.0    0.0  250655  26.000   NaN        S  NaN   NaN
# 2  40.0    0.0    0.0   31418  13.000   NaN        S    9   NaN
# 3  31.0    1.0    1.0  363291  20.525   NaN        S  C D   NaN
# 4   NaN    2.0    0.0  367226  23.250   NaN        Q   16   NaN
#
#                            home.dest
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3  Strood, Kent, England Detroit, MI
# 4                                NaN

# %%
# age => mean
# fare => median
# cabin => mode
# embarked => mode
# boat => mode
# body => mean?
# home.dest => drop?

data['age'].fillna(value=data['age'].mean(), inplace=True)
data['fare'].fillna(value=data['fare'].median(), inplace=True)
data['cabin'].fillna(value=np.random.choice(data['cabin'].mode()), inplace=True)
data['embarked'].fillna(value=data['embarked'].mode().iloc[0], inplace=True)
data['boat'].fillna(value=data['boat'].mode().iloc[0], inplace=True)
data['body'].fillna(value=data['body'].mean(), inplace=True)
data.drop('home.dest', axis=1, inplace=True)

# %%
data['sex'] = le.fit_transform(data['sex'])
data['name'] = le.fit_transform(data['name'])
data['ticket'] = le.fit_transform(data['ticket'])
data['cabin'] = le.fit_transform(data['cabin'])
data['embarked'] = le.fit_transform(data['embarked'])
data['boat'] = le.fit_transform(data['boat'])

# %%
'''plt.scatter(X_tr[:,7], Y_tr[:], c=Y_tr.reshape((-1,)))
# plt.xlabel()
plt.show()'''
# Out:
# 'plt.scatter(X_tr[:,7], Y_tr[:], c=Y_tr.reshape((-1,)))\n# plt.xlabel()\nplt.show()'

# %%
for col in data.columns:
    print(col, len(data[col].value_counts()))
# Out:
# pclass 3
# survived 2
# name 1007
# sex 2
# age 97
# sibsp 7
# parch 8
# ticket 751
# fare 251
# cabin 155
# embarked 3
# boat 25
# body 99

# %%
data.head()
# Out:
#    pclass  survived  name  sex        age  sibsp  parch  ticket    fare  \
# 0     3.0       0.0   668    0  29.838978    0.0    0.0     482   7.750
# 1     2.0       0.0   620    1  39.000000    0.0    0.0     185  26.000
# 2     2.0       1.0   848    0  40.000000    0.0    0.0     281  13.000
# 3     3.0       1.0   358    0  31.000000    1.0    1.0     468  20.525
# 4     3.0       1.0   586    0  29.838978    2.0    0.0     489  23.250
#
#    cabin  embarked  boat        body
# 0    153         1    22  164.489796
# 1    153         2    22  164.489796
# 2    153         2    19  164.489796
# 3    153         2    23  164.489796
# 4    153         1     9  164.489796

# %%
a = data['name']
print(a.min(), a.max())
data['name'] = np.interp(a, (a.min(), a.max()), (0.0, 100.6))
data.head()
# Out:
# 0 1006
#    pclass  survived  name  sex        age  sibsp  parch  ticket    fare  \
# 0     3.0       0.0  66.8    0  29.838978    0.0    0.0     482   7.750
# 1     2.0       0.0  62.0    1  39.000000    0.0    0.0     185  26.000
# 2     2.0       1.0  84.8    0  40.000000    0.0    0.0     281  13.000
# 3     3.0       1.0  35.8    0  31.000000    1.0    1.0     468  20.525
# 4     3.0       1.0  58.6    0  29.838978    2.0    0.0     489  23.250
#
#    cabin  embarked  boat        body
# 0    153         1    22  164.489796
# 1    153         2    22  164.489796
# 2    153         2    19  164.489796
# 3    153         2    23  164.489796
# 4    153         1     9  164.489796

# %%
a = data['ticket']
print(a.min(), a.max())
data['ticket'] = np.interp(a, (a.min(), a.max()), (0.0, 75))
data.head()
# Out:
# 0 750
#    pclass  survived  name  sex        age  sibsp  parch  ticket    fare  \
# 0     3.0       0.0  66.8    0  29.838978    0.0    0.0    48.2   7.750
# 1     2.0       0.0  62.0    1  39.000000    0.0    0.0    18.5  26.000
# 2     2.0       1.0  84.8    0  40.000000    0.0    0.0    28.1  13.000
# 3     3.0       1.0  35.8    0  31.000000    1.0    1.0    46.8  20.525
# 4     3.0       1.0  58.6    0  29.838978    2.0    0.0    48.9  23.250
#
#    cabin  embarked  boat        body
# 0    153         1    22  164.489796
# 1    153         2    22  164.489796
# 2    153         2    19  164.489796
# 3    153         2    23  164.489796
# 4    153         1     9  164.489796

# %%
a = data['body']
print(a.min(), a.max())
data['body'] = np.interp(a, (a.min(), a.max()), (1.0, 32.8))
data.head()
# Out:
# 1.0 328.0
#    pclass  survived  name  sex        age  sibsp  parch  ticket    fare  \
# 0     3.0       0.0  66.8    0  29.838978    0.0    0.0    48.2   7.750
# 1     2.0       0.0  62.0    1  39.000000    0.0    0.0    18.5  26.000
# 2     2.0       1.0  84.8    0  40.000000    0.0    0.0    28.1  13.000
# 3     3.0       1.0  35.8    0  31.000000    1.0    1.0    46.8  20.525
# 4     3.0       1.0  58.6    0  29.838978    2.0    0.0    48.9  23.250
#
#    cabin  embarked  boat       body
# 0    153         1    22  16.899008
# 1    153         2    22  16.899008
# 2    153         2    19  16.899008
# 3    153         2    23  16.899008
# 4    153         1     9  16.899008

# %%
a = data['age']
print(a.min(), a.max())
data['age'] = np.interp(a, (a.min(), a.max()), (0.0, 80))
data.head()
# Out:
# 0.3333 80.0
#    pclass  survived  name  sex        age  sibsp  parch  ticket    fare  \
# 0     3.0       0.0  66.8    0  29.629120    0.0    0.0    48.2   7.750
# 1     2.0       0.0  62.0    1  38.828469    0.0    0.0    18.5  26.000
# 2     2.0       1.0  84.8    0  39.832653    0.0    0.0    28.1  13.000
# 3     3.0       1.0  35.8    0  30.795000    1.0    1.0    46.8  20.525
# 4     3.0       1.0  58.6    0  29.629120    2.0    0.0    48.9  23.250
#
#    cabin  embarked  boat       body
# 0    153         1    22  16.899008
# 1    153         2    22  16.899008
# 2    153         2    19  16.899008
# 3    153         2    23  16.899008
# 4    153         1     9  16.899008

# %%
a = data['boat']
print(a.min(), a.max())
data['boat'] = np.interp(a, (a.min(), a.max()), (0.0, 24))
data.head()
# Out:
# 0 24
#    pclass  survived  name  sex        age  sibsp  parch  ticket    fare  \
# 0     3.0       0.0  66.8    0  29.629120    0.0    0.0    48.2   7.750
# 1     2.0       0.0  62.0    1  38.828469    0.0    0.0    18.5  26.000
# 2     2.0       1.0  84.8    0  39.832653    0.0    0.0    28.1  13.000
# 3     3.0       1.0  35.8    0  30.795000    1.0    1.0    46.8  20.525
# 4     3.0       1.0  58.6    0  29.629120    2.0    0.0    48.9  23.250
#
#    cabin  embarked  boat       body
# 0    153         1  22.0  16.899008
# 1    153         2  22.0  16.899008
# 2    153         2  19.0  16.899008
# 3    153         2  23.0  16.899008
# 4    153         1   9.0  16.899008

# %%
plt.scatter(np.linspace(0,600,1009), data['fare'])

# %%
a = data['fare']
print(a.min(), a.max())
data['fare'] = np.interp(a, (a.min(), a.max()), (0.0, 51.2))
data.head()
# Out:
# 0.0 512.3292
#    pclass  survived  name  sex        age  sibsp  parch  ticket      fare  \
# 0     3.0       0.0  66.8    0  29.629120    0.0    0.0    48.2  0.774502
# 1     2.0       0.0  62.0    1  38.828469    0.0    0.0    18.5  2.598329
# 2     2.0       1.0  84.8    0  39.832653    0.0    0.0    28.1  1.299165
# 3     3.0       1.0  35.8    0  30.795000    1.0    1.0    46.8  2.051181
# 4     3.0       1.0  58.6    0  29.629120    2.0    0.0    48.9  2.323506
#
#    cabin  embarked  boat       body
# 0    153         1  22.0  16.899008
# 1    153         2  22.0  16.899008
# 2    153         2  19.0  16.899008
# 3    153         2  23.0  16.899008
# 4    153         1   9.0  16.899008

# %%
a = data['cabin']
print(a.min(), a.max())
data['cabin'] = np.interp(a, (a.min(), a.max()), (0.0, 15.4))
data.head()
# Out:
# 0 154
#    pclass  survived  name  sex        age  sibsp  parch  ticket      fare  \
# 0     3.0       0.0  66.8    0  29.629120    0.0    0.0    48.2  0.774502
# 1     2.0       0.0  62.0    1  38.828469    0.0    0.0    18.5  2.598329
# 2     2.0       1.0  84.8    0  39.832653    0.0    0.0    28.1  1.299165
# 3     3.0       1.0  35.8    0  30.795000    1.0    1.0    46.8  2.051181
# 4     3.0       1.0  58.6    0  29.629120    2.0    0.0    48.9  2.323506
#
#    cabin  embarked  boat       body
# 0   15.3         1  22.0  16.899008
# 1   15.3         2  22.0  16.899008
# 2   15.3         2  19.0  16.899008
# 3   15.3         2  23.0  16.899008
# 4   15.3         1   9.0  16.899008

# %%
print(min(data['ticket']), max(data['ticket']))
# Out:
# 0.0 75.0

# %%
d2.head()
# Out:
#    pclass                              name     sex   age  sibsp  parch  \
# 0     1.0  Flynn, Mr. John Irwin ("Irving")    male  36.0    0.0    0.0
# 1     3.0      Sage, Miss. Constance Gladys  female   NaN    8.0    2.0
# 2     1.0             Rood, Mr. Hugh Roscoe    male   NaN    0.0    0.0
# 3     2.0      Gillespie, Mr. William Henry    male  34.0    0.0    0.0
# 4     2.0        Collander, Mr. Erik Gustaf    male  28.0    0.0    0.0
#
#      ticket     fare cabin embarked boat  body  \
# 0  PC 17474  26.3875   E25        S    5   NaN
# 1  CA. 2343  69.5500   NaN        S  NaN   NaN
# 2    113767  50.0000   A32        S  NaN   NaN
# 3     12233  13.0000   NaN        S  NaN   NaN
# 4    248740  13.0000   NaN        S  NaN   NaN
#
#                            home.dest
# 0                       Brooklyn, NY
# 1                                NaN
# 2                        Seattle, WA
# 3                      Vancouver, BC
# 4  Helsinki, Finland Ashtabula, Ohio

# %%
d2['age'].fillna(value=d2['age'].mean(), inplace=True)
d2['fare'].fillna(value=d2['fare'].median(), inplace=True)
d2['cabin'].fillna(value=np.random.choice(d2['cabin'].mode()), inplace=True)
d2['embarked'].fillna(value=d2['embarked'].mode().iloc[0], inplace=True)
d2['boat'].fillna(value=d2['boat'].mode().iloc[0], inplace=True)
d2['body'].fillna(value=d2['body'].mean(), inplace=True)
d2.drop('home.dest', axis=1, inplace=True)

# %%
d2['sex'] = le.fit_transform(d2['sex'])
d2['name'] = le.fit_transform(d2['name'])
d2['ticket'] = le.fit_transform(d2['ticket'])
d2['cabin'] = le.fit_transform(d2['cabin'])
d2['embarked'] = le.fit_transform(d2['embarked'])
d2['boat'] = le.fit_transform(d2['boat'])

# %%
d2.head()
# Out:
#    pclass  name  sex        age  sibsp  parch  ticket     fare  cabin  \
# 0     1.0    84    1  36.000000    0.0    0.0     229  26.3875     49
# 1     3.0   254    0  30.027422    8.0    2.0     224  69.5500     50
# 2     1.0   240    1  30.027422    0.0    0.0       9  50.0000      2
# 3     2.0    94    1  34.000000    0.0    0.0      24  13.0000     50
# 4     2.0    51    1  28.000000    0.0    0.0      67  13.0000     50
#
#    embarked  boat        body
# 0         2    13  145.130435
# 1         2     6  145.130435
# 2         2     6  145.130435
# 3         2     6  145.130435
# 4         2     6  145.130435

# %%
alldata = data.values

X_ts = d2.values

print("train XY:", alldata.shape)
print("test X:", X_ts.shape)

Y_tr = alldata[:, 1].reshape((-1, 1))
print("train Y:", Y_tr.shape)

X1 = alldata[:, 0].reshape((-1, 1))
X2 = alldata[:, 2:]

# print(X1.shape, X2.shape)
X_tr = np.hstack((X1, X2))

print("train X & Y:", X_tr.shape, Y_tr.shape)
# Out:
# train XY: (1009, 13)
# test X: (300, 12)
# train Y: (1009, 1)
# train X & Y: (1009, 12) (1009, 1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
yt = Y_tr.reshape(Y_tr.shape[0], )
lr.fit(X_tr, yt)
print(lr.coef_, lr.intercept_)
lr.score(X_tr, yt)
# Out:
# [[-0.08975106  0.00277733 -2.03925963  0.00878127 -0.16327041 -0.14792196
#   -0.01207433  0.07827514  0.07042636 -0.37323756 -0.42407853  0.1229724 ]] [6.42667347]
# /Users/riagupta/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.9137760158572844

# %%
def hypothesis(x, w, b):
#     print(w)
#     print(x)
    return sigmoid(np.dot(x, w) + b)

def sigmoid(z):
#     print(z)
    z = z/10
    return 1.0/(1.0 + np.exp(-1.0*z))

def error(X, Y, w, b):
    m = X.shape[0]
    err = 0.0
    
    for i in range(m):
        hx = hypothesis(X[i], w, b)
#         print(hx)
        v = (Y[i]*np.log2(1.0*hx) + (1-Y[i])*np.log2(1.0-hx))
        err += v
#         print(v)
    return -err/m 

def get_gradient(X, Y, w, b, batch_size = 1):
    m = X.shape[0]
    grad_w = np.zeros(w.shape)
    grad_b = 0
    
#     indices = np.arange(m)
#     np.random.shuffle(indices)
#     indices = indices[:batch_size]
    
    for i in range(m):
        hx = hypothesis(X[i], w, b)
        grad_w += (Y[i] - hx)*X[i]
        grad_b += (Y[i] - hx)
        
    return grad_w/m, grad_b/m

def gradientDescent(X, Y, lr=0.01):
    w = np.random.random(X.shape[1])
#     w = np.zeros(X.shape[1])
    b = np.random.random()
    
    error_list = []
    
    for i in range(2000):
        grad_w, grad_b = get_gradient(X, Y, w, b)
        w = w + lr*grad_w
        b = b + lr*grad_b
        err = error(X, Y, w, b)
#         if (i%10):
        error_list.append(err)
#         acc_list.append(get_accuracy())
    return error_list, w, b

def predict(x, w, b):
    confidence = hypothesis(x, w, b)
    if confidence < 0.5:
        return 0.0
    else:
        return 1.0
    
def get_accuracy(x_test, y_test, w, b):
    y_pred = []
    for i in range(y_test.shape[0]):
        y_pred.append(predict(x_test[i], w, b))
        
    y_pred = np.array(y_pred)
    y_test = y_test.reshape((-1,))
#     print(y_pred)
#     print(y_test)
#     print((y_test.reshape((-1,))))
#     print(matches, y_test.shape[0])
#     print(y_pred == y_test)
    return float((y_pred == y_test).sum())/y_test.shape[0]

# %%
def test(X, w, b):
    y_test = []
    for i in range(X.shape[0]):
        y_test.append(predict(X[i], w, b))
    return y_test

# %%
error_list, final_w, final_b = gradientDescent(X_tr, Y_tr)
print(final_w, final_b)
# Out:
# [ 0.18056932  0.03722764 -0.22834863  0.16391847 -0.06441788  0.77219461
#  -0.0968923   1.3851853   0.93629256 -0.14592179 -3.33658451  2.02165232] [0.58104268]

# %%
# [ 0.24836312  0.041863    0.09004341  0.13671924  0.20206188  0.73954058
#  -0.06090373  1.0056842   1.37618127  0.04543449 -2.90029744  1.6728166 ] [0.95963339]

# [[ 0.09045862  0.00252709 -2.04235879  0.00800854 -0.15498885 -0.1511889
#   -0.01172079  0.00646826  0.01550381 -0.37674759 -0.4228957   0.01070201]] [6.28751403]

print(get_accuracy(X_tr, Y_tr, final_w, final_b))
# plt.scatter(np.linspace(0,10, 6000), error_list)
plt.plot(error_list)
plt.show()
print(error_list[-1])
print(len(error_list))
# Out:
# 0.8553022794846382
# [0.50277224]
# 2000

# %%
print(np.array(error_list).min())
# Out:
# 0.5027722411950964

# %%
res = test(X_ts, final_w, final_b)

# %%
print(len(res))
# Out:
# 300

# %%
dff = pd.DataFrame(res)
dff.to_csv("logreg.csv")

# %%
x = np.linspace(2,8,10)
y = -(final_w[0]*x + final_b)/final_w[1]
print(y.shape)

print(x)
print(y)

plt.plot(x,y)
# Out:
# (10,)
# [2.         2.66666667 3.33333333 4.         4.66666667 5.33333333
#  6.         6.66666667 7.33333333 8.        ]
# [-216.7662129  -216.20818551 -215.65015812 -215.09213073 -214.53410333
#  -213.97607594 -213.41804855 -212.86002115 -212.30199376 -211.74396637]

# %%
plt.scatter(xts[:,0], xts[:,1], c=yts.reshape((19,)))
plt.plot(x,y, c='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-7cb803fab950> in <module>()
# ----> 1 plt.scatter(xts[:,0], xts[:,1], c=yts.reshape((19,)))
#       2 plt.plot(x,y, c='red')
#       3 plt.show()
#
# NameError: name 'xts' is not defined

# %%
plt.scatter(X[:,0], X[:,1], c=Y.reshape((99,)))
plt.plot(x,y, c='red')
plt.show()

# %%
print(get_accuracy(xts, yts, final_w, final_b))
print(get_accuracy(xtr, ytr, final_w, final_b))
print(get_accuracy(X, Y, final_w, final_b))
